# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# 1) The sex of the mice were practically evenly split with 50.2% male mice and 49.8% female mice.
# 2) In the box plot, the drugs Capomulin and Ramicane had the lowest final tumor volume between the four treatment groups.
# 3) Looking at mouse s185 across timepoints, Capomulin decreased tumor volume from 45 mm3 to 25.47 mm3--a  43% reduction.
# 4) Looking at the Capomulin group, there was a strong statiscially signficant postive correlation of mouse weight and avg tumor volume (r = 0.84, p-value = 1.03e0-7).
# 5) Calcuation of the linear regression model shows a coefficient of determination (r-squared) of 0.709,  This represents the percent of the data that is the closest to the line of best fit.  Since r = 0.84 and r 2 = 0.709, means 70.9% of the total variation in  averge tumor volume can be explained by the linear relationship between mouse weight and average tumor volume (as described by the regression equation).  The other 29.1% of the total variation in average tumor volume remains unexplained.

# %%
# Dependencies and Setup
from matplotlib import pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)
mouse_metadata.shape
# Out:
# (249, 5)

# %%
study_results.shape
# Out:
# (1893, 4)

# %%
# Combine the data into a single dataset
merge_table = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
merge_table
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
merge_table['Mouse ID'].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicateRowsDF = merge_table[merge_table.duplicated(['Mouse ID', 'Timepoint'])]
duplicateRowsDF
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_data = merge_table.drop_duplicates(subset=['Mouse ID', 'Timepoint'], keep='first').reset_index(drop=True)

# %%
# Checking the number of mice in the clean DataFrame.
clean_mouse_data['Mouse ID'].nunique()
# Out:
# 249

# %%
clean_mouse_data.head(50)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# ...

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance,standard deviation, and SEM of the tumor volume for each regimen
grouped_by_drug = clean_mouse_data.groupby(['Drug Regimen'])
mean_tumor_volume = grouped_by_drug['Tumor Volume (mm3)'].mean()
median_tumor_volume = grouped_by_drug['Tumor Volume (mm3)'].median()
var_tumor_volume = grouped_by_drug['Tumor Volume (mm3)'].var()
std_tumor_volume = grouped_by_drug['Tumor Volume (mm3)'].std()
sem_tumor_volume = grouped_by_drug['Tumor Volume (mm3)'].sem()

# This method is the most straighforward, creating multiple series and putting them all together at the end.

grouped_by_drug.count().head(10)
# Out:
#               Mouse ID  Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin          230  230         230         230        230
# Ceftamin           178  178         178         178        178
# Infubinol          178  178         178         178        178
# Ketapril           188  188         188         188        188
# Naftisol           186  186         186         186        186
# Placebo            181  181         181         181        181
# Propriva           156  156         156         156        156
# Ramicane           228  228         228         228        228
# Stelasyn           181  181         181         181        181
# Zoniferol          182  182         182         182        182
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin                    230               230
# Ceftamin                     178               178
# Infubinol                    178               178
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
drug_summary_table = pd.DataFrame({"Mean": mean_tumor_volume,
                                   "Median": median_tumor_volume,
                                   "Variance": var_tumor_volume,
                                   "Std Dev": std_tumor_volume,
                                   "SEM": sem_tumor_volume})
# This method produces everything in a single groupby function
print("Tumor Volume")
print("*"*80)
drug_summary_table
# Out:
# Tumor Volume
# ********************************************************************************
#                    Mean     Median   Variance   Std Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
total_mice_df = pd.DataFrame(grouped_by_drug['Mouse ID'].nunique())

# Filter the DataFrame down only to those columns to chart

# Use DataFrame.plot() in order to create a bar chart of the data
total_mice_df.plot(kind="bar", figsize=(10,5), color='b', legend=False, fontsize = 14, rot = 45)

# Set a title for the chart
plt.title("Total Number Of Mice For Each Treatment", fontsize = 20)
plt.xlabel("Drug Regimen", fontsize = 14)
plt.ylabel("Number of Mice", fontsize = 14)
plt.tight_layout()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
x_axis = np.arange(len(grouped_by_drug))
y_axis = grouped_by_drug['Mouse ID'].nunique()
labels = ['Capomulin', 'Ceftamin','Infubinol','Ketapril','Naftisol','Placebo','Propriva', 'Ramicane','Stelasyn','Zoniferol']

plt.figure(figsize=(10,5))
plt.bar(x_axis, y_axis, color='b',width = 0.5)
x = plt.xticks(x_axis, labels, rotation= 45, fontsize = 14)
x = plt.yticks( fontsize = 14)

plt.title("Total Number Of Mice For Each Treatment", fontsize = 20)
plt.xlabel("Drug Regimen", fontsize = 14)
plt.ylabel("Number of Mice", fontsize = 14)

plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

grouped_ID_data = clean_mouse_data.groupby(['Mouse ID'])
sex_df = pd.DataFrame(grouped_ID_data['Sex'].unique().value_counts())
plot = sex_df.plot.pie(y= 'Sex', figsize=(5, 5), autopct="%1.3f%%")

# %%
##### Generate a pie plot showing the distribution of female versus male mice using pyplot

# Labels for the sections of our pie chart
labels = ["Female", "Male"]

# The values of each section of the pie chart
sizes = [124, 125]

# The colors of each section of the pie chart
colors = ["orange", "blue"]

plt.pie(sizes, labels=labels, colors=colors, autopct="%1.3f%%",startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x205a5381108>,
# ...
#  [Text(-0.006939175976765929, -1.0999781124353174, 'Female'),
#   Text(0.0069391759767660635, 1.0999781124353174, 'Male')],
#  [Text(-0.003785005078235961, -0.5999880613283548, '49.799%'),
#   Text(0.003785005078236034, 0.5999880613283548, '50.201%')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_tumor = clean_mouse_data.groupby([ 'Mouse ID'])['Timepoint'].max()
max_tumor = max_tumor.reset_index()


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_data = max_tumor.merge(clean_mouse_data, on=['Mouse ID','Timepoint'], how='left')
merged_data.head(25)
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a203         45    Infubinol  Female          20          23
# 1      a251         45    Infubinol  Female          21          25
# 2      a262         45      Placebo  Female          17          29
# 3      a275         45     Ceftamin  Female          20          28
# 4      a366         30     Stelasyn  Female          16          29
# 5      a401         45    Zoniferol  Female           8          25
# 6      a411         45     Ramicane    Male           3          22
# 7      a444         45     Ramicane  Female          10          25
# 8      a457         10     Ketapril  Female          11          30
# 9      a492         45     Stelasyn    Male          20          25
# 10     a520         45     Ramicane    Male          13          21
# 11     a577         30    Infubinol  Female           6          25
# 12     a644         45     Ramicane  Female           7          17
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
RX_labels = ['Capomulin', 'Ceftamin','Infubinol', 'Ramicane']


# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Locate the rows which contain mice on each drug and get the tumor volumes


for drug in RX_labels:
    final_tumor_vol = merged_data.loc[merged_data['Drug Regimen'] == drug, "Tumor Volume (mm3)"]
    tumor_vol_data.append(final_tumor_vol)
    quartiles = final_tumor_vol.quantile([.25,.5,.75])
    lowerq = quartiles[.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = final_tumor_vol.loc[(final_tumor_vol < lower_bound) | (final_tumor_vol > upper_bound)]
    print(outliers)
# Out:
# Series([], Name: Tumor Volume (mm3), dtype: float64)
# Series([], Name: Tumor Volume (mm3), dtype: float64)
# 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
 
fig7, ax7 = plt.subplots()
ax7.set_title('Box Plot for 4 Drug Regimens Effects on Tumor Volume')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks([1, 2, 3, 4], RX_labels) 
ax7.boxplot(tumor_vol_data)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

capomulin_single_mouse = clean_mouse_data.iloc[10:19, 5:7]
capomulin_single_mouse = capomulin_single_mouse.set_index('Timepoint')
capomulin_single_mouse

# Use DataFrame.plot() in order to create a bar chart of the data
capomulin_single_mouse.plot(kind="line", figsize=(10,5))

# Set a title for the chart
plt.title("Capomulin Effect on Mouse s185 Tumor Volume")

plt.show()
plt.tight_layout()
capomulin_single_mouse.head(10)
# Out:
#            Tumor Volume (mm3)
# Timepoint
# 0                   45.000000
# 5                   43.878496
# 10                  37.614948
# 15                  38.177232
# 20                  36.866876
# 25                  33.949940
# 30                  32.959671
# 35                  28.328531
# 40                  25.472143

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
capomulin_regimen = clean_mouse_data.loc[clean_mouse_data['Drug Regimen'] == 'Capomulin']
capomulin_regimen_grouped = capomulin_regimen.groupby(['Mouse ID'])

capomulin_regimen.head(25)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
# 20     x401    Capomulin  Female          16          15          0
# 21     x401    Capomulin  Female          16          15          5
# 22     x401    Capomulin  Female          16          15         10
# ...

# %%
avg_tv = capomulin_regimen_grouped["Tumor Volume (mm3)"].mean()
weight = capomulin_regimen_grouped['Weight (g)'].median()
avg_tv_mousewt_df = pd.DataFrame({"Mouse Weight(g)": weight,
                                    "Avg Tumor Volume(mm3)": avg_tv })
avg_tv_mousewt_df.head(25)
# Out:
#           Mouse Weight(g)  Avg Tumor Volume(mm3)
# Mouse ID
# b128                   22              41.963636
# b742                   21              40.083699
# f966                   17              36.505973
# g288                   19              41.990097
# g316                   22              44.613344
# i557                   24              44.805810
# i738                   20              39.141053
# j119                   23              44.465236
# j246                   21              43.216925
# l509                   21              44.434474
# l897                   19              42.507261
# m601                   17              34.847470
# m957                   19              39.049816
# r157                   25              45.798970
# r554                   17              36.509212
# r944                   25              43.367364
# s185                   17              34.559143
# s710                   23              42.803733
# ...

# %%
# Use DataFrame.plot() in order to create a bar chart of the data

ax1 = avg_tv_mousewt_df.plot.scatter(x='Mouse Weight(g)',
                      y='Avg Tumor Volume(mm3)',
                      c='DarkBlue')
# Set a title for the chart
plt.title("Mouse Weight versus Average Tumor Volume for Capomulin Group")

plt.show()
plt.tight_layout()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation = st.pearsonr(weight, avg_tv)

print(f"The correlation coefficient (r) is {round(correlation[0],2)}")
print(f"The p-value is {correlation[1]}")
# Out:
# The correlation coefficient (r) is 0.84
# The p-value is 1.322572243471279e-07

# %%
x_values = weight
y_values = avg_tv

# Run the regression and store each of the returned values
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate the predictions for each value of x (Mouse Weight)
regress_values = x_values * slope + intercept

# Create the linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The line of best fit: {line_eq}")
# Out:
# The line of best fit: y = 0.95x + 21.55

# %%
plt.figure(figsize=(10,8))
# Plot observations
plt.scatter(x_values, y_values, alpha=0.8)

# Plot the regression line
plt.plot(x_values, regress_values, "red")

# Add the linear equation to the plot
plt.annotate(line_eq, (15, 44), fontsize=15, color="red")
plt.annotate(f"R2 = {round(rvalue**2,3)}", (15, 43), fontsize=15, color="red")

# Add labels
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

# calculate r2
print(f"The r-squared is: {rvalue**2}")

plt.show()
# Out:
# The r-squared is: 0.7088568047708717
